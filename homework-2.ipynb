# %% [markdown]
# #Part 1
# 1.

# %% [markdown]
# **Hello** everyone! This is my *homework* 2.

# %% [markdown]
# 2.

# %% [markdown]
# # Food
# ## desserts
# ### cookies and creme icecream

# %% [markdown]
# 3.

# %% [markdown]
# My favorite fruits:
# * starfruit
# * dragonfruit
# * grapes

# %% [markdown]
# # Part 2
# 1.

# %%
a=5
b=10
c=a+b
print(c)
# Out:
# 15

# %% [markdown]
# 2.

# %% [markdown]
# 6+2x(5-3^2)+4/26+2x(5-32)+4/2    original problem
#
# 6+2x(5-9)+4/26+2x(-27)+4/2       Parentheses + Exponent
#
# 6+2x(-4)+4/26+2x(-27)+4/2        Multiplication + Division
#
# 6+(-8)+.15384+(-53)+2            Addition + Subtraction
#
# =-52.84616                       Answer rounded

# %%
6+2*(5-3**2)+4/26+2*(5-32)+4/2
# Out:
# -53.84615384615385

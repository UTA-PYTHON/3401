# %% [markdown]
# QUESTION 2 HAS BEEN DONE BEFORE QUESTION 1

# %% [markdown]
# Questions:
#
# Part 2: Python Basics
# Variable Assignment
#
# Assign the number 5 to a variable named a.
# Assign the number 10 to a variable named b.
# Compute the sum of a and b and assign it to a variable named c. Print out the value of c.
# PEMDAS
#
# Given the equation
# 6+2×(5−32)+4/2:
# Solve the equation step-by-step, following the PEMDAS order, and comment each step in the Jupyter cell.
# Compute the final answer using Python and display the result.

# %%
a=5
b=10
c = a+b
print(c)
# Out:
# 15

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#1st step: Parentheses
a = (5-(3*3))
##also had exponential
print(a)

b = (5-32)
print(b)
# Out:
# -4
# -27

# %%
#2nd step: Multiplication
c = 2 *a
d = 2*b
print(c)
print(d)
# Out:
# -8
# -54

# %%
#3rd: Division
e = 4/26
f = 4/2
print(e)
print(f)
# Out:
# 0.15384615384615385
# 2.0

# %%
#Subtraction and addition together
final = 6+ c + e + d + f
print(final)
# Out:
# -53.84615384615385

# %% [markdown]
# Part 1: Markdown in Jupyter Notebook
# Bold and Italics
#
# Write a sentence where one word is in bold and another is in italics.
# Headers
#
# Create a hierarchy of headers from # (largest) to ### (smallest). Make up titles for each header level.
# Lists
#
# Create a bulleted list of your three favorite fruits

# %% [markdown]
# In my sentence, this is *italic* and this is **bold**

# %% [markdown]
# #Largest Header

# %% [markdown]
# ##Medium Header

# %% [markdown]
# ###Smallest Header

# %% [markdown]
# My 3 favorite fruits are:
# * apple
# * banana
# * orange

# %%
# Out:
# 15
